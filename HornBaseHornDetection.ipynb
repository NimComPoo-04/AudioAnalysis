# %% [markdown]
# # Detecting horn vs no horn

# %%
import librosa
import numpy as np
import pandas as pd

import os
import sys

# %%
g = os.walk('env/dataset/Dataset')
for dir_name, dirs, files in g:
    for f in files:
        print(f)
# Out:
# _J_10_B_V.wav
# C_5_A_V_.wav
# C_4_A_S.wav
# J_3_S_N7.wav
# J_1_B_N7.wav
# C_8_B_N9.wav
# C_2_B_S.wav
# C_5_B_S.wav
# J_4_S_L_.wav
# J_8_S_N9.wav
# C_2_S_L_.wav
# _J_5_B_V.wav
# _J_6_A_S.wav
# C_9_S_N8.wav
# C_2_A_S_.wav
# J_4_S_V_.wav
# _J_3_S_L.wav
# J_4_S_N9.wav
# C_3_S_N9.wav
# J_10_A_S.wav
# J_5_A_N6.wav
# C_9_B_N1.wav
# _C_9_S_S.wav
# J_1_B_N2.wav
# _C_3_A_S.wav
# C_6_B_S.wav
# J_4_A_L_.wav
# C_10_B_N2.wav
# J_5_S_L.wav
# _C_6_S_S.wav
# C_1_B_N6.wav
# _J_8_S_S.wav
# C_1_A_V_.wav
# J_4_B_V.wav
# J_10_S_V_.wav
# J_10_B_N9.wav
# C_4_B_S.wav
# C_6_A_V.wav
# _C_9_S_L.wav
# C_4_A_N4.wav
# J_7_B_S_.wav
# J_1_S_N3.wav
# J_7_A_N1.wav
# C_3_B_N1.wav
# J_5_A_V.wav
# J_1_S_N8.wav
# J_7_A_N7.wav
# C_5_A_L.wav
# _C_10_B_V.wav
# J_7_A_N9.wav
# C_6_A_L.wav
# C_10_A_N4.wav
# J_4_A_V.wav
# C_9_S_N6.wav
# _J_6_B_S.wav
# J_10_B_V.wav
# C_1_A_N3.wav
# C_6_S_S_.wav
# J_2_B_S.wav
# J_10_A_V_.wav
# J_5_A_S_.wav
# J_6_B_N4.wav
# C_10_S_S_.wav
# J_2_B_N7.wav
# J_7_A_S.wav
# C_6_A_N9.wav
# C_7_B_N4.wav
# ...
