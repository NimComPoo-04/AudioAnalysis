# %%
from rich import print

import librosa
import soundfile as sf
import tensorflow as tf
import kagglehub
import scipy
import pandas as pd
import numpy as np
import pyaudio
import seaborn as sns

import os
import sys
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779084376.327646    4793 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1779084378.235232    4793 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779084386.296699    4793 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
yamnet_model = None
yamnet_classes = None

audio_dataframe = None
audio_embeddings = None

# %%
def load_yamnet_model():
    global yamnet_model, yamnet_classes
    path = kagglehub.model_download("google/yamnet/tensorFlow2/yamnet")
    yamnet_model = tf.saved_model.load(path)
    class_map_path = f'{path}/assets/yamnet_class_map.csv'
    yamnet_classes = pd.read_csv(class_map_path)['display_name'].tolist()

# %%
def load_csv_file(file):
    return pd.read_csv(file)

# %%
def load_audio_file(audio_file):
    audio, _ = librosa.load(audio_file, sr=16000, mono=True)
    intervals = librosa.effects.split(y=audio, top_db=5)
    nospace = np.concat([ audio[a:b] for a, b in intervals ])
    return nospace

# %%
def execute_model(audio):
    score, embeddings, _ = yamnet_model(audio)
    return score, embeddings

# %% [markdown]
# ## Load the Yamnent Model

# %%
load_yamnet_model()
# Out:
# E0000 00:00:1779084503.722132    4793 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
labels = load_csv_file('ProtoV1/labels.csv')

# %%
labels
# Out:
#                 File Name     Label
# 0  545015_10485775-lq.mp3  car-horn
