# %%
import tensorflow as tf
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778664170.388454   19514 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1778664171.540700   19514 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778664179.450244   19514 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
ldmod = tf.keras.models.load_model('my_model.keras')
lite_converter = tf.lite.TFLiteConverter.from_keras_model(ldmod)
limod = lite_converter.convert()
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmphws7lfod/assets
# INFO:tensorflow:Assets written to: /tmp/tmphws7lfod/assets
# Saved artifact at '/tmp/tmphws7lfod'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 87, 256, 1), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   133688758699216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133688758701328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133688758701136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133688758700368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133688758700176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133688758701904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133688758701520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133688758702480: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
